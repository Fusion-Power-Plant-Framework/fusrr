# %%
from fusrr.reactor import Reactor
from fusrr.views import View
from IPython.display import Image

# %% [markdown]
# # **Example View in the Rendering pipeline**
# **This notebook demonstrates the usage of the rendering pipeline module and provides an example of how to generate some views for visualising reactors**

# %% [markdown]
# Importing the Reactor class from the reactor file, to create a reactor from the file name the user must call the `reactor_from_file` method and input the MFILE of choice.

# %%
example_reactor = Reactor.reactor_from_file("large_tokamak_MFILE.DAT")
# Out:
# Key 'vvblgapi' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapi' not in MFILE. KeyError! Check MFILE
# Key 'rminoro' not in MFILE. KeyError! Check MFILE
# Key 'rminoro' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapo' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapo' not in MFILE. KeyError! Check MFILE
# Key 'thshield_vb' not in MFILE. KeyError! Check MFILE
# Key 'thshield_vb' not in MFILE. KeyError! Check MFILE
# Key 'iohcl' not in MFILE. KeyError! Check MFILE
# Key 'iohcl' not in MFILE. KeyError! Check MFILE
# Key 'rpf(01)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(01)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(02)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(02)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(03)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(03)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(04)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(04)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(05)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(05)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(06)' not in MFILE. KeyError! Check MFILE
# Key 'rpf(06)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(01)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(01)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(02)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(02)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(03)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(03)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(04)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(04)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(05)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(05)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(06)' not in MFILE. KeyError! Check MFILE
# Key 'zpf(06)' not in MFILE. KeyError! Check MFILE
# Key 'pfdr01' not in MFILE. KeyError! Check MFILE
# Key 'pfdr01' not in MFILE. KeyError! Check MFILE
# Key 'pfdr02' not in MFILE. KeyError! Check MFILE
# Key 'pfdr02' not in MFILE. KeyError! Check MFILE
# Key 'pfdr03' not in MFILE. KeyError! Check MFILE
# Key 'pfdr03' not in MFILE. KeyError! Check MFILE
# Key 'pfdr04' not in MFILE. KeyError! Check MFILE
# Key 'pfdr04' not in MFILE. KeyError! Check MFILE
# Key 'pfdr05' not in MFILE. KeyError! Check MFILE
# Key 'pfdr05' not in MFILE. KeyError! Check MFILE
# Key 'pfdr06' not in MFILE. KeyError! Check MFILE
# Key 'pfdr06' not in MFILE. KeyError! Check MFILE
# Key 'pfdz01' not in MFILE. KeyError! Check MFILE
# Key 'pfdz01' not in MFILE. KeyError! Check MFILE
# Key 'pfdz02' not in MFILE. KeyError! Check MFILE
# Key 'pfdz02' not in MFILE. KeyError! Check MFILE
# Key 'pfdz03' not in MFILE. KeyError! Check MFILE
# Key 'pfdz03' not in MFILE. KeyError! Check MFILE
# Key 'pfdz04' not in MFILE. KeyError! Check MFILE
# Key 'pfdz04' not in MFILE. KeyError! Check MFILE
# Key 'pfdz05' not in MFILE. KeyError! Check MFILE
# Key 'pfdz05' not in MFILE. KeyError! Check MFILE
# Key 'pfdz06' not in MFILE. KeyError! Check MFILE
# Key 'pfdz06' not in MFILE. KeyError! Check MFILE
# 8.400021
# 4.654700000000001
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/clair/development/fusrr-pipeline/examples/2D_reactor_from_file.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/home/clair/development/fusrr-pipeline/examples/2D_reactor_from_file.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> example_reactor = Reactor.reactor_from_file("large_tokamak_MFILE.DAT")
#
# File ~/development/fusrr-pipeline/fusrr/reactor.py:31, in Reactor.reactor_from_file(cls, input_file_path)
#      29 for component in BlenderComponent.__subclasses__():
#      30     try:
# ---> 31         cdict[component.__name__.lower()] = component(reactor_params)
#      32     except NotImplementedError:
#      33         continue
#
# File ~/development/fusrr-pipeline/fusrr/components.py:217, in VacuumVessel.__init__(self, params, colour)
#     215     shapes.extend(self._get_bluemira_comps())
#     216 else:
# --> 217     self.create_shape()
#     218     self.select_spin("vacuum vessel")
#     219     shapes.extend(self._select_objects("vacuum vessel"))
#
# File ~/development/fusrr-pipeline/fusrr/components.py:281, in VacuumVessel.create_shape(self)
#     279 for _x, _y in zip((vvg.rs_1, vvg.rs_2), (vvg.zs_1, vvg.zs_2)):
#     280     self.create_mesh(_x, _y, name="vacuum vessel")
# --> 281 join_obj(vacuum_vessel_list)
#     282 make_face_from_vertices("vacuum vessel")
#     284 # try like tf :
#     285 # verts in tf are lists of rs and zs
#     286 # verts_list = [[vvg.rs_1, vvg.zs_1], [vvg.rs_2, vvg.zs_2]]
#    (...)
#     292 #     change_to_mesh(obj=obj)
#     293 #     make_face_from_vertices(obj)
#
# File ~/development/fusrr-pipeline/fusrr/blender_tools.py:143, in join_obj(names)
#     141 for obj_name in names:
#     142     selected_objects = bpy.data.objects.get(str(obj_name))
# --> 143     selected_objects.select_set(True)
#     145 bpy.context.view_layer.objects.active = bpy.context.scene.objects[str(names[0])]
#     146 bpy.ops.object.join()
#
# AttributeError: 'NoneType' object has no attribute 'select_set'

# %% [markdown]
# Once the reactor has been created a view can be chosen to visualise the reactor. A default 2D polodial cross section is set up.

# %%
example_view = View(example_reactor)
example_view.save_image("example_view_reactor")
# Out:
# Fra:1 Mem:57.70M (Peak 58.78M) | Time:00:00.09 | Syncing vacuum vessel
# Fra:1 Mem:63.46M (Peak 63.69M) | Time:00:00.12 | Rendering 1 / 64 samples
# Fra:1 Mem:59.32M (Peak 63.69M) | Time:00:00.29 | Rendering 26 / 64 samples
# Fra:1 Mem:59.32M (Peak 63.69M) | Time:00:00.40 | Rendering 51 / 64 samples
# Fra:1 Mem:59.32M (Peak 63.69M) | Time:00:00.46 | Rendering 64 / 64 samples
# Saved: 'example_view_reactor.png'
#  Time: 00:00.57 (Saving: 00:00.07)
# OpenColorIO Error: ExponentTransform validation failed: Parameter 8.38861e+06 is greater than upper bound 100

# %%
Image(url="example_view_reactor.png")
# Out:
# <img src="example_view_reactor.png"/>
