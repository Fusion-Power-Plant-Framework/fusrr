# %%
from fusrr.reactor import Reactor
from fusrr.views import View
from IPython.display import Image

# %% [markdown]
# # **Example View in the Rendering pipeline**
# **This notebook demonstrates the usage of the rendering pipeline module and provides an example of how to generate some views for visualising reactors**

# %% [markdown]
# Importing the Reactor class from the reactor file, to create a reactor from the file name the user must call the `reactor_from_file` method and input the MFILE of choice.

# %%
example_reactor = Reactor.reactor_from_file("EUDEMO_MFILE.DAT")
# Out:
# Key 'thshield_ib' not in MFILE. KeyError! Check MFILE
# Key 'thshield_ib' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapi' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapi' not in MFILE. KeyError! Check MFILE
# Key 'rminoro' not in MFILE. KeyError! Check MFILE
# Key 'rminoro' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapo' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapo' not in MFILE. KeyError! Check MFILE
# Key 'thshield_ob' not in MFILE. KeyError! Check MFILE
# Key 'thshield_ob' not in MFILE. KeyError! Check MFILE
# Key 'thshield_vb' not in MFILE. KeyError! Check MFILE
# Key 'thshield_vb' not in MFILE. KeyError! Check MFILE
# Key 'iohcl' not in MFILE. KeyError! Check MFILE
# Key 'iohcl' not in MFILE. KeyError! Check MFILE

# %% [markdown]
# Once the reactor has been created a view can be chosen to visualise the reactor. A default 2D polodial cross section is set up.

# %%
example_view = View(example_reactor)
example_view.save_image("example_view_reactor")
# Out:
# Fra:1 Mem:58.91M (Peak 60.00M) | Time:00:00.33 | Syncing plasma
# Fra:1 Mem:67.96M (Peak 68.35M) | Time:00:00.34 | Syncing Tf_coils
# Fra:1 Mem:70.09M (Peak 70.20M) | Time:00:00.35 | Syncing cryostat
# Fra:1 Mem:70.36M (Peak 70.36M) | Time:00:00.35 | Syncing pf_coil0
# Fra:1 Mem:70.45M (Peak 70.45M) | Time:00:00.35 | Syncing pf_coil1
# Fra:1 Mem:70.54M (Peak 70.54M) | Time:00:00.35 | Syncing pf_coil2
# Fra:1 Mem:70.63M (Peak 70.63M) | Time:00:00.35 | Syncing pf_coil3
# Fra:1 Mem:70.73M (Peak 70.73M) | Time:00:00.35 | Syncing pf_coil4
# Fra:1 Mem:70.82M (Peak 70.82M) | Time:00:00.35 | Syncing pf_coil5
# Fra:1 Mem:70.91M (Peak 70.91M) | Time:00:00.35 | Syncing central_coil
# Fra:1 Mem:76.89M (Peak 77.70M) | Time:00:00.38 | Rendering 1 / 64 samples
# Fra:1 Mem:63.55M (Peak 77.70M) | Time:00:00.40 | Rendering 26 / 64 samples
# Fra:1 Mem:63.55M (Peak 77.70M) | Time:00:00.40 | Rendering 51 / 64 samples
# Fra:1 Mem:63.55M (Peak 77.70M) | Time:00:00.40 | Rendering 64 / 64 samples
# Saved: 'example_view_reactor.png'
# Time: 00:01.21 (Saving: 00:00.09)
# OpenColorIO Error: ExponentTransform validation failed: Parameter 8.38861e+06 is greater than upper bound 100

# %%
Image(url="example_view_reactor.png")
# Out:
# <img src="example_view_reactor.png"/>
