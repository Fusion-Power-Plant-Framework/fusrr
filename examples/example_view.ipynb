# %% [markdown]
# # **Example View in the Rendering pipeline**
# **This notebook demonstrates the usage of the rendering pipeline module and provides an example of how to generate some views for visualising reactors**

# %% [markdown]
# This notebook must be run in the directory where `MFILE.DAT` and `EUDEMO.gltf` test files live.
#
# Importing the Reactor class from the reactor file, to create a reactor from the file name the user must call the `reactor_from_file` method and input the MFILE of choice.

# %%
from renderingpipeline.reactor import Reactor

example_reactor = Reactor.reactor_from_file("MFILE.DAT")
# Out:
# Key 'thshield_ib' not in MFILE. KeyError! Check MFILE
# Key 'thshield_ib' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapi' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapi' not in MFILE. KeyError! Check MFILE
# Key 'rminoro' not in MFILE. KeyError! Check MFILE
# Key 'rminoro' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapo' not in MFILE. KeyError! Check MFILE
# Key 'vvblgapo' not in MFILE. KeyError! Check MFILE
# Key 'thshield_ob' not in MFILE. KeyError! Check MFILE
# Key 'thshield_ob' not in MFILE. KeyError! Check MFILE
# Key 'thshield_vb' not in MFILE. KeyError! Check MFILE
# Key 'thshield_vb' not in MFILE. KeyError! Check MFILE
# Key 'iohcl' not in MFILE. KeyError! Check MFILE
# Key 'iohcl' not in MFILE. KeyError! Check MFILE

# %% [markdown]
# Once the reactor has been created a view can be chosen to visualise the reactor. At present, will use default view.

# %%
from renderingpipeline.views import View
example_view = View(example_reactor)
example_view.make_3d()
example_reactor.save_image("example_view_reactor")
# Out:
# <renderingpipeline.reactor.Reactor object at 0x7ff5089f0c10>
# component = plasma
# obj = <bpy_struct, Object("plasma") at 0x55995cf6a3c8>
# component = pf_coil0
# obj = <bpy_struct, Object("pf_coil0") at 0x55995d4a77e8>
# component = pf_coil1
# obj = <bpy_struct, Object("pf_coil1") at 0x55995d4ceee8>
# component = pf_coil2
# obj = <bpy_struct, Object("pf_coil2") at 0x55995d4daca8>
# component = pf_coil3
# obj = <bpy_struct, Object("pf_coil3") at 0x55995d4e5b78>
# component = pf_coil4
# obj = <bpy_struct, Object("pf_coil4") at 0x55995d4f0f78>
# component = pf_coil5
# obj = <bpy_struct, Object("pf_coil5") at 0x55995d4fb5e8>
# component = central_coil
# obj = <bpy_struct, Object("central_coil") at 0x55995d5078a8>
# Fra:1 Mem:68.86M (Peak 69.95M) | Time:00:00.15 | Syncing Light
# Fra:1 Mem:68.86M (Peak 69.95M) | Time:00:00.15 | Syncing Camera
# Fra:1 Mem:68.87M (Peak 69.95M) | Time:00:00.15 | Syncing plasma
# Fra:1 Mem:96.32M (Peak 97.89M) | Time:00:00.18 | Syncing Sun
# Fra:1 Mem:96.32M (Peak 97.89M) | Time:00:00.18 | Syncing Sun.001
# Fra:1 Mem:96.33M (Peak 97.89M) | Time:00:00.18 | Syncing Upper_Outer_wall
# Fra:1 Mem:96.34M (Peak 97.89M) | Time:00:00.18 | Syncing Lower_Outer_wall
# Fra:1 Mem:96.36M (Peak 97.89M) | Time:00:00.18 | Syncing Upper_wall
# Fra:1 Mem:96.37M (Peak 97.89M) | Time:00:00.18 | Syncing Lower_wall
# Fra:1 Mem:96.39M (Peak 97.89M) | Time:00:00.18 | Syncing line_object
# Fra:1 Mem:96.40M (Peak 97.89M) | Time:00:00.18 | Syncing pf_coil0
# Fra:1 Mem:96.68M (Peak 97.89M) | Time:00:00.19 | Syncing pf_coil1
# Fra:1 Mem:96.96M (Peak 97.89M) | Time:00:00.19 | Syncing pf_coil2
# Fra:1 Mem:97.24M (Peak 97.89M) | Time:00:00.19 | Syncing pf_coil3
# Fra:1 Mem:97.53M (Peak 97.89M) | Time:00:00.19 | Syncing pf_coil4
# Fra:1 Mem:97.81M (Peak 97.89M) | Time:00:00.19 | Syncing pf_coil5
# Fra:1 Mem:98.12M (Peak 98.12M) | Time:00:00.19 | Syncing central_coil
# Fra:1 Mem:98.34M (Peak 98.34M) | Time:00:00.19 | Syncing Tf.1
# Fra:1 Mem:98.37M (Peak 98.37M) | Time:00:00.19 | Syncing Tf.2
# Fra:1 Mem:98.38M (Peak 98.38M) | Time:00:00.19 | Syncing Tf.3
# Fra:1 Mem:98.40M (Peak 98.40M) | Time:00:00.19 | Syncing Tf.4
# Fra:1 Mem:98.41M (Peak 98.41M) | Time:00:00.19 | Syncing Tf.5
# Fra:1 Mem:98.40M (Peak 98.41M) | Time:00:00.21 | Rendering 1 / 64 samples
# Fra:1 Mem:76.72M (Peak 98.41M) | Time:00:02.64 | Rendering 26 / 64 samples
# Fra:1 Mem:76.72M (Peak 98.41M) | Time:00:05.11 | Rendering 51 / 64 samples
# Fra:1 Mem:76.72M (Peak 98.41M) | Time:00:06.22 | Rendering 64 / 64 samples
# Saved: 'example_view_reactor.png'
#  Time: 00:06.93 (Saving: 00:00.58)

# %%
from IPython.display import Image

Image(url="example_view_reactor.png")
# Out:
# <img src="example_view_reactor.png"/>
